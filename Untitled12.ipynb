# %% [markdown]
# <a href="https://colab.research.google.com/github/Ronakss/Assignment-2-/blob/master/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
# Reading the file
# The source of the code can be found here: https://www.kaggle.com/datasets/souvikahmed071/social-media-and-mental-health
df = pd.read_csv('/content/mental_health2425v8in (2).csv')
df.head(2)
# Out:
#    Birth Year state_1 general_health                      phq9_1  \
# 0        2000      MD      Very Good                Several days
# 1        2001      SC           Good  More than half of the days
#
#                        phq9_2            phq9_3            phq9_4  \
# 0                Several days        Not at all      Several days
# 1  More than half of the days  Nearly every day  Nearly every day
#
#              phq9_5        phq9_6                      phq9_7  ...  \
# 0        Not at all    Not at all  More than half of the days  ...
# 1  Nearly every day  Several days            Nearly every day  ...
#
#   acha_12months_any_comp     sex  fulltime  international  race_1  race_2  \
# 0                      2  Female       Yes             No     NaN     NaN
# 1                      0  Female       Yes             No     NaN     NaN
#
#    race_3                     race_4  race_5  race_6
# 0     NaN  Asian or Pacific Islander     NaN     NaN
# ...

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Assuming df is your DataFrame loaded earlier, replace with actual DataFrame name if different
_df_23 = df.copy()  # Creating a copy of the DataFrame and assigning it to _df_23

plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['phq9_3'].value_counts()
    for x_label, grp in _df_23.groupby('phq9_2')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('phq9_2')
_ = plt.ylabel('phq9_3')

# %%
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Assuming df is your DataFrame loaded earlier
# Create _df_22, potentially based on df, similar to _df_23
_df_22 = df.copy()  # Or any other relevant operations to create _df_22

plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['phq9_2'].value_counts()
    for x_label, grp in _df_22.groupby('phq9_1')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('phq9_1')
_ = plt.ylabel('phq9_2')

# %%
# Assuming df is your DataFrame loaded earlier, replace with actual DataFrame name if different
_df_23 = df.copy()  # Creating a copy of the DataFrame and assigning it to _df_23

plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['phq9_3'].value_counts()
    for x_label, grp in _df_23.groupby('phq9_2')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('phq9_2')
_ = plt.ylabel('phq9_3')
# Importing necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# Assuming df is your DataFrame loaded earlier
# Create _df_22, potentially based on df, similar to _df_23
_df_22 = df.copy()  # Or any other relevant operations to create _df_22

plt.subplots(figsize=(8, 8))
df_2dhist = pd.DataFrame({
    x_label: grp['phq9_2'].value_counts()
    for x_label, grp in _df_22.groupby('phq9_1')
})
sns.heatmap(df_2dhist, cmap='viridis')
plt.xlabel('phq9_1')
_ = plt.ylabel('phq9_2')
from matplotlib import pyplot as plt

# Assuming 'df' is your original DataFrame
# Create _df_19, likely extracting or manipulating data from 'df'
_df_19 = df[['phq9_3NUM']].copy()  # Replace 'phq9_3NUM' with the actual column if different

# Now you can proceed with plotting
_df_19['phq9_3NUM'].plot(kind='line', figsize=(8, 4), title='phq9_3NUM')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns

def _plot_series(series, series_name, series_index=0):
  palette = list(sns.palettes.mpl_palette('Dark2'))
  # Check if 'year_1' column exists in _df_15, if not replace 'Birth Year' with actual column name containing year data
  xs = series['Birth Year'] if 'Birth Year' in series else series['year_1']
  ys = series['acha_12months_any_18NUM']

  plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])

fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
df_sorted = _df_15.sort_values('Birth Year', ascending=True) # Replace 'Birth Year' if necessary

for i, (series_name, series) in enumerate(df_sorted.groupby('phq9_2')):
  _plot_series(series, series_name, i)
  fig.legend(title='phq9_2', bbox_to_anchor=(1, 1), loc='upper left')

sns.despine(fig=fig, ax=ax)
plt.xlabel('Birth Year') # Replace 'Birth Year' with actual column name if modified in _plot_series
_ = plt.ylabel('acha_12months_any_18NUM')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-63cf585fd597> in <cell line: 0>()
#      11
#      12 fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# ---> 13 df_sorted = _df_15.sort_values('Birth Year', ascending=True) # Replace 'Birth Year' if necessary
#      14
#      15 for i, (series_name, series) in enumerate(df_sorted.groupby('phq9_2')):
#
# NameError: name '_df_15' is not defined

# %%
from matplotlib import pyplot as plt
import pandas as pd # Assuming 'df' is your original DataFrame

# Creating _df_11 - Replace this with your actual data or logic
_df_11 = pd.DataFrame({
    'phq9_3NUM': df['phq9_3NUM'], # Assuming 'phq9_3NUM' is a column in your 'df'
    'phq9_4NUM': df['phq9_4NUM']  # Assuming 'phq9_4NUM' is a column in your 'df'
})

_df_11.plot(kind='scatter', x='phq9_3NUM', y='phq9_4NUM', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import pandas as pd # Assuming 'df' is your original DataFrame

# Creating _df_10 - Replace with your actual data or logic if needed
_df_10 = pd.DataFrame({
    'phq9_2NUM': df['phq9_2NUM'], # Assuming 'phq9_2NUM' is a column in your 'df'
    'phq9_3NUM': df['phq9_3NUM']  # Assuming 'phq9_3NUM' is a column in your 'df'
})

_df_10.plot(kind='scatter', x='phq9_2NUM', y='phq9_3NUM', s=32, alpha=.8)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd # Assuming you have 'df' defined

# Assuming you want to analyze 'phq9_2' distribution, replace 'df' if needed
# Define _df_7 based on your original DataFrame (df)
_df_7 = df[['phq9_2']].copy() # Replace 'phq9_2' if the column name is different

_df_7.groupby('phq9_2').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
# Assuming 'df' is your original DataFrame and it contains the column 'phq9_1'
df.groupby('phq9_1').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import pandas as pd

# Assuming 'df' is your original DataFrame
# Creating _df_2 - This part needs your attention. Replace with actual logic
_df_2 = df[['phq9_2NUM']].copy()  # Example: Selecting the 'phq9_2NUM' column from 'df'

_df_2['phq9_2NUM'].plot(kind='hist', bins=20, title='phq9_2NUM')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import pandas as pd # Make sure pandas is imported

# Creating _df_3 - This part needs your attention. Replace with actual logic
_df_3 = df[['phq9_3NUM']].copy()  # Example: Selecting the 'phq9_3NUM' column from 'df'

_df_3['phq9_3NUM'].plot(kind='hist', bins=20, title='phq9_3NUM')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# Observing the shape of the file
df.shape

# %%
# General information about the file
df.info()

# %%
import pandas as pd # Importing pandas and aliasing it as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
